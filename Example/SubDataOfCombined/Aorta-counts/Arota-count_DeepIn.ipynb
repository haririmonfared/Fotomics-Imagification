# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA, KernelPCA
from sklearn.manifold import TSNE
from scipy.spatial import ConvexHull
from matplotlib import pyplot as plt
import inspect


class ImageTransformer:
    """Transform features to an image matrix using dimensionality reduction
    This class takes in data normalized between 0 and 1 and converts it to a
    CNN compatible 'image' matrix
    """

    def __init__(self, feature_extractor='tsne', pixels=100,
                 random_state=None, n_jobs=None):
        """Generate an ImageTransformer instance
        Args:
            feature_extractor: string of value ('tsne', 'pca', 'kpca') or a
                class instance with method `fit_transform` that returns a
                2-dimensional array of extracted features.
            pixels: int (square matrix) or tuple of ints (height, width) that
                defines the size of the image matrix.
            random_state: int or RandomState. Determines the random number
                generator, if present, of a string defined feature_extractor.
            n_jobs: The number of parallel jobs to run for a string defined
                feature_extractor.
        """
        self.random_state = random_state
        self.n_jobs = n_jobs

        if isinstance(feature_extractor, str):
            fe = feature_extractor.casefold()
            if fe == 'tsne'.casefold():
                fe = TSNE(
                    n_components=2, metric='cosine',
                    random_state=self.random_state,
                    n_jobs=self.n_jobs)
            elif fe == 'pca'.casefold():
                fe = PCA(n_components=2,
                         random_state=self.random_state)
            elif fe == 'kpca'.casefold():
                fe = KernelPCA(
                    n_components=2, kernel='rbf',
                    random_state=self.random_state,
                    n_jobs=self.n_jobs)
            else:
                raise ValueError(("Feature extraction method '{}' not accepted"
                                  ).format(feature_extractor))
            self._fe = fe
        elif hasattr(feature_extractor, 'fit_transform') and \
                inspect.ismethod(feature_extractor.fit_transform):
            self._fe = feature_extractor
        else:
            raise TypeError('Parameter feature_extractor is not a '
                            'string nor has method "fit_transform"')

        if isinstance(pixels, int):
            pixels = (pixels, pixels)
        self._pixels = pixels
        self._xrot = None

    def fit(self, X, y=None, plot=False):
        """Train the image transformer from the training set (X)
        Args:
            X: {array-like, sparse matrix} of shape (n_samples, n_features)
            y: Ignored. Present for continuity with scikit-learn
            plot: boolean of whether to produce a scatter plot showing the
                feature reduction, hull points, and minimum bounding rectangle
        Returns:
            self: object
        """
        # perform dimensionality reduction
        x_new = self._fe.fit_transform(X.T)
        # get the convex hull for the points
        chvertices = ConvexHull(x_new).vertices
        hull_points = x_new[chvertices]
        # determine the minimum bounding rectangle
        mbr, mbr_rot = self._minimum_bounding_rectangle(hull_points)
        # rotate the matrix
        # save the rotated matrix in case user wants to change the pixel size
        self._xrot = np.dot(mbr_rot, x_new.T).T
        # determine feature coordinates based on pixel dimension
        self._calculate_coords()
        # plot rotation diagram if requested
        if plot is True:
            plt.scatter(x_new[:, 0], x_new[:, 1], s=1,
                        cmap=plt.cm.get_cmap("jet", 10), alpha=0.2)
            plt.fill(x_new[chvertices, 0], x_new[chvertices, 1],
                     edgecolor='r', fill=False)
            plt.fill(mbr[:, 0], mbr[:, 1], edgecolor='g', fill=False)
            plt.gca().set_aspect('equal', adjustable='box')
            plt.show()
        return self

    @property
    def pixels(self):
        """The image matrix dimensions
        Returns:
            tuple: the image matrix dimensions (height, width)
        """
        return self._pixels

    @pixels.setter
    def pixels(self, pixels):
        """Set the image matrix dimension
        Args:
            pixels: int or tuple with the dimensions (height, width)
            of the image matrix
        """
        if isinstance(pixels, int):
            pixels = (pixels, pixels)
        self._pixels = pixels
        # recalculate coordinates if already fit
        if hasattr(self, '_coords'):
            self._calculate_coords()

    def _calculate_coords(self):
        """Calculate the matrix coordinates of each feature based on the
        pixel dimensions.
        """
        ax0_coord = np.digitize(
            self._xrot[:, 0],
            bins=np.linspace(min(self._xrot[:, 0]), max(self._xrot[:, 0]),
                             self._pixels[0])
        ) - 1
        ax1_coord = np.digitize(
            self._xrot[:, 1],
            bins=np.linspace(min(self._xrot[:, 1]), max(self._xrot[:, 1]),
                             self._pixels[1])
        ) - 1
        self._coords = np.stack((ax0_coord, ax1_coord), axis=1)

    def transform(self, X, format='rgb', empty_value=0):
        """Transform the input matrix into image matrices
        Args:
            X: {array-like, sparse matrix} of shape (n_samples, n_features)
                where n_features matches the training set.
            format: The format of the image matrix to return. 'scalar' return a
                array of shape (M, N). 'rgb' returns an numpy.ndarray of shape
                (M, N, 3) that is compatible with PIL.
            empty_value: numeric value to fill elements where no features are
                mapped. Default = 0.
        Returns:
            A list of n_samples numpy matrices of dimensions set by
            the pixel parameter
        """
        img_coords = pd.DataFrame(np.vstack((
            self._coords.T,
            X
        )).T).groupby([0, 1], as_index=False).mean()

        img_matrices = []
        blank_mat = np.zeros(self._pixels)
        if empty_value != 0:
            blank_mat[:] = empty_value
        for z in range(2, img_coords.shape[1]):
            img_matrix = blank_mat.copy()
            img_matrix[img_coords[0].astype(int),
                       img_coords[1].astype(int)] = img_coords[z]
            img_matrices.append(img_matrix)

        if format=='rgb':
            img_matrices = np.array([self._mat_to_rgb(m) for m in img_matrices])
        elif format=='scalar':
            pass
        else:
            raise ValueError(("'{}' not accepted for parameter 'format'")
                             .format(format))

        return img_matrices

    def fit_transform(self, X, **kwargs):
        """Train the image transformer from the training set (X) and return
        the transformed data.
        Args:
            X: {array-like, sparse matrix} of shape (n_samples, n_features)
        Returns:
            A list of n_samples numpy matrices of dimensions set by
            the pixel parameter
        """
        self.fit(X)
        return self.transform(X, **kwargs)

    def feature_density_matrix(self):
        """Generate image matrix with feature counts per pixel
        Returns:
            img_matrix (ndarray): matrix with feature counts per pixel
        """
        fdmat = np.zeros(self._pixels)
        np.add.at(fdmat, tuple(self._coords.T), 1)
        return fdmat

    def coords(self):
        """Get feature coordinates
        Returns:
            ndarray: the pixel coordinates for features
        """
        return self._coords.copy()

    @staticmethod
    def _minimum_bounding_rectangle(hull_points):
        """Find the smallest bounding rectangle for a set of points.
        Modified from JesseBuesking at https://stackoverflow.com/a/33619018
        Returns a set of points representing the corners of the bounding box.
        Args:
            hull_points : an nx2 matrix of hull coordinates
        Returns:
            (tuple): tuple containing
                coords (ndarray): coordinates of the corners of the rectangle
                rotmat (ndarray): rotation matrix to align edges of rectangle
                    to x and y
        """

        pi2 = np.pi / 2
        # calculate edge angles
        edges = hull_points[1:] - hull_points[:-1]
        angles = np.arctan2(edges[:, 1], edges[:, 0])
        angles = np.abs(np.mod(angles, pi2))
        angles = np.unique(angles)
        # find rotation matrices
        rotations = np.vstack([
            np.cos(angles),
            -np.sin(angles),
            np.sin(angles),
            np.cos(angles)]).T
        rotations = rotations.reshape((-1, 2, 2))
        # apply rotations to the hull
        rot_points = np.dot(rotations, hull_points.T)
        # find the bounding points
        min_x = np.nanmin(rot_points[:, 0], axis=1)
        max_x = np.nanmax(rot_points[:, 0], axis=1)
        min_y = np.nanmin(rot_points[:, 1], axis=1)
        max_y = np.nanmax(rot_points[:, 1], axis=1)
        # find the box with the best area
        areas = (max_x - min_x) * (max_y - min_y)
        best_idx = np.argmin(areas)
        # return the best box
        x1 = max_x[best_idx]
        x2 = min_x[best_idx]
        y1 = max_y[best_idx]
        y2 = min_y[best_idx]
        rotmat = rotations[best_idx]
        # generate coordinates
        coords = np.zeros((4, 2))
        coords[0] = np.dot([x1, y2], rotmat)
        coords[1] = np.dot([x2, y2], rotmat)
        coords[2] = np.dot([x2, y1], rotmat)
        coords[3] = np.dot([x1, y1], rotmat)

        return coords, rotmat

    @staticmethod
    def _mat_to_rgb(mat):
        """Convert image matrix to numpy rgb format
        Args:
            mat: {array-like} (M, N)
        Returns:
            An numpy.ndarry (M, N, 3) with orignal values repeated across
            RGB channels.
        """
        return np.repeat(mat[:, :, np.newaxis], 3, axis=2)


class LogScaler:
    """Log normalize and scale data
    Log normalization and scaling procedure as described as norm-2 in the
    DeepInsight paper supplementary information.
    """

    def __init__(self):
        self._min0 = None
        self._max = None
        pass

    def fit(self, X, y=None):
        self._min0 = X.min(axis=0)
        self._max = np.log(X + np.abs(self._min0) + 1).max()

    def fit_transform(self, X, y=None):
        self._min0 = X.min(axis=0)
        X_norm = np.log(X + np.abs(self._min0) + 1)
        self._max = X_norm.max()
        return X_norm / self._max

    def transform(self, X, y=None):
        X_norm = np.log(X + np.abs(self._min0) + 1).clip(0, None)
        return (X_norm / self._max).clip(0, 1)

# %%
import h5py

# %%
h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Aorta-counts_x_train.h5','r')
x_train = h5f['dataset_1'][:]
h5f.close()


h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Aorta-counts_x_test.h5','r')
x_test = h5f['dataset_1'][:]
h5f.close()

h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Aorta-counts_y_train.h5','r')
y_train = h5f['dataset_1'][:]
h5f.close()

h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Aorta-counts_y_test.h5','r')
y_test = h5f['dataset_1'][:]
h5f.close()

# %%
x_train.shape
# Out:
# (326, 23433)

# %%
x_test.shape
# Out:
# (82, 23433)

# %%
y_train.shape
# Out:
# (326,)

# %%
y_test.shape
# Out:
# (82,)

# %%
x_train = np.nan_to_num(x_train)
x_test = np.nan_to_num(x_test)
sum_train = np.sum(x_train,axis=1)
sum_train = sum_train.reshape(sum_train.shape[0],-1)
sum_test = np.sum(x_test,axis=1)
sum_test = sum_test.reshape(sum_test.shape[0],-1)


x_train = np.divide(x_train, sum_train)
x_test =  np.divide(x_test, sum_test)
print(x_train.shape)
# Out:
# (326, 23433)

# %%
import gc

del sum_train
del sum_test

gc.collect()
# Out:
# 132

# %%
ln = LogScaler()

x_train = ln.fit_transform(x_train)
x_test = ln.transform(x_test)

# %%
it = ImageTransformer(pixels=124)
_ = it.fit(x_train, plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:827: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   FutureWarning,

# %%
del _
gc.collect()
# Out:
# 2334

# %%
x_train = it.transform(x_train)
x_train.shape
# Out:
# (326, 124, 124, 3)

# %%
x_test = it.transform(x_test)
x_test.shape
# Out:
# (82, 124, 124, 3)

# %%
print("Train img")
plt.figure(figsize=(15,4))

#subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(1,10,figsize=(30,30)) 

for i in range(10):
    axarr[i].imshow(x_train[i])
    print(y_train[i])
# Out:
# Train img
# 1.0
# 3.0
# 0.0
# 1.0
# 1.0
# 0.0
# 0.0
# 0.0
# 3.0
# 1.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from keras import layers

# %%
unique_classes = np.unique(y_train)

# %%
num_classes = len(unique_classes)
print(num_classes)
# Out:
# 4

# %%
df_y_train = to_categorical(y_train,num_classes=num_classes)

# %%
print(x_train.shape)
print(df_y_train.shape)
# Out:
# (326, 124, 124, 3)
# (326, 4)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint , ReduceLROnPlateau


model = Sequential()
model.add(Conv2D(64,(3,3),input_shape=(124,124,3)) )
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3) ))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64))
model.add(Dense(num_classes))
model.add(Activation('sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['categorical_accuracy'])

earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
mcp_save = ModelCheckpoint('.mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='auto')
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, verbose=1, min_delta=1e-4, mode='auto')

model.fit(x_train, df_y_train, batch_size=32, epochs=90, verbose=1, callbacks=[earlyStopping, mcp_save, reduce_lr_loss], validation_split=0.2)
# Out:
# Epoch 1/90
# 9/9 [==============================] - 10s 985ms/step - loss: 0.5981 - categorical_accuracy: 0.4154 - val_loss: 0.5456 - val_categorical_accuracy: 0.4848 - lr: 0.0010
# Epoch 2/90
# 9/9 [==============================] - 11s 1s/step - loss: 0.5381 - categorical_accuracy: 0.4538 - val_loss: 0.5248 - val_categorical_accuracy: 0.4848 - lr: 0.0010
# Epoch 3/90
# 9/9 [==============================] - 9s 961ms/step - loss: 0.5229 - categorical_accuracy: 0.4538 - val_loss: 0.5197 - val_categorical_accuracy: 0.4848 - lr: 0.0010
# Epoch 4/90
# 9/9 [==============================] - 9s 967ms/step - loss: 0.5097 - categorical_accuracy: 0.4731 - val_loss: 0.5108 - val_categorical_accuracy: 0.5758 - lr: 0.0010
# Epoch 5/90
# 9/9 [==============================] - 9s 968ms/step - loss: 0.4994 - categorical_accuracy: 0.6269 - val_loss: 0.4691 - val_categorical_accuracy: 0.6212 - lr: 0.0010
# Epoch 6/90
# 9/9 [==============================] - 9s 967ms/step - loss: 0.4504 - categorical_accuracy: 0.6077 - val_loss: 0.4160 - val_categorical_accuracy: 0.6061 - lr: 0.0010
# Epoch 7/90
# 9/9 [==============================] - 9s 967ms/step - loss: 0.3883 - categorical_accuracy: 0.6423 - val_loss: 0.4009 - val_categorical_accuracy: 0.6212 - lr: 0.0010
# Epoch 8/90
# 9/9 [==============================] - 9s 949ms/step - loss: 0.3259 - categorical_accuracy: 0.7115 - val_loss: 0.4177 - val_categorical_accuracy: 0.8030 - lr: 0.0010
# Epoch 9/90
# 9/9 [==============================] - 9s 954ms/step - loss: 0.2937 - categorical_accuracy: 0.8077 - val_loss: 0.3914 - val_categorical_accuracy: 0.6970 - lr: 0.0010
# Epoch 10/90
# 9/9 [==============================] - 9s 951ms/step - loss: 0.2405 - categorical_accuracy: 0.8115 - val_loss: 0.2445 - val_categorical_accuracy: 0.8636 - lr: 0.0010
# Epoch 11/90
# 9/9 [==============================] - 9s 954ms/step - loss: 0.1769 - categorical_accuracy: 0.8962 - val_loss: 0.1929 - val_categorical_accuracy: 0.8636 - lr: 0.0010
# Epoch 12/90
# 9/9 [==============================] - 9s 940ms/step - loss: 0.1291 - categorical_accuracy: 0.9308 - val_loss: 0.2051 - val_categorical_accuracy: 0.8485 - lr: 0.0010
# Epoch 13/90
# 9/9 [==============================] - 9s 954ms/step - loss: 0.0956 - categorical_accuracy: 0.9538 - val_loss: 0.1338 - val_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 14/90
# 9/9 [==============================] - 9s 946ms/step - loss: 0.0747 - categorical_accuracy: 0.9654 - val_loss: 0.1512 - val_categorical_accuracy: 0.8939 - lr: 0.0010
# Epoch 15/90
# 9/9 [==============================] - 9s 954ms/step - loss: 0.0639 - categorical_accuracy: 0.9731 - val_loss: 0.1318 - val_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 16/90
# 9/9 [==============================] - 9s 941ms/step - loss: 0.0634 - categorical_accuracy: 0.9654 - val_loss: 0.1365 - val_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 17/90
# 9/9 [==============================] - 9s 1s/step - loss: 0.0530 - categorical_accuracy: 0.9808 - val_loss: 0.1358 - val_categorical_accuracy: 0.8939 - lr: 0.0010
# Epoch 18/90
# 9/9 [==============================] - 10s 1s/step - loss: 0.0435 - categorical_accuracy: 0.9808 - val_loss: 0.1526 - val_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 19/90
# 9/9 [==============================] - 11s 1s/step - loss: 0.0354 - categorical_accuracy: 0.9846 - val_loss: 0.1252 - val_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 20/90
# 9/9 [==============================] - 9s 958ms/step - loss: 0.0379 - categorical_accuracy: 0.9769 - val_loss: 0.1651 - val_categorical_accuracy: 0.9242 - lr: 0.0010
# Epoch 21/90
# 9/9 [==============================] - 9s 951ms/step - loss: 0.0309 - categorical_accuracy: 0.9885 - val_loss: 0.1323 - val_categorical_accuracy: 0.9242 - lr: 0.0010
# Epoch 22/90
# 9/9 [==============================] - 9s 945ms/step - loss: 0.0257 - categorical_accuracy: 0.9846 - val_loss: 0.1693 - val_categorical_accuracy: 0.8788 - lr: 0.0010
# Epoch 23/90
# 9/9 [==============================] - 9s 945ms/step - loss: 0.0231 - categorical_accuracy: 0.9885 - val_loss: 0.1354 - val_categorical_accuracy: 0.9545 - lr: 0.0010
# Epoch 24/90
# 9/9 [==============================] - 9s 951ms/step - loss: 0.0250 - categorical_accuracy: 0.9962 - val_loss: 0.1820 - val_categorical_accuracy: 0.8939 - lr: 0.0010
# Epoch 25/90
# 9/9 [==============================] - 9s 943ms/step - loss: 0.0185 - categorical_accuracy: 0.9923 - val_loss: 0.1307 - val_categorical_accuracy: 0.9242 - lr: 0.0010
# Epoch 26/90
# 9/9 [==============================] - 9s 946ms/step - loss: 0.0141 - categorical_accuracy: 0.9962 - val_loss: 0.1433 - val_categorical_accuracy: 0.9242 - lr: 0.0010
# Epoch 27/90
# 9/9 [==============================] - ETA: 0s - loss: 0.0150 - categorical_accuracy: 0.9923
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 9/9 [==============================] - 9s 942ms/step - loss: 0.0150 - categorical_accuracy: 0.9923 - val_loss: 0.2426 - val_categorical_accuracy: 0.8788 - lr: 0.0010
# Epoch 28/90
# 9/9 [==============================] - 9s 946ms/step - loss: 0.0258 - categorical_accuracy: 0.9885 - val_loss: 0.1421 - val_categorical_accuracy: 0.9242 - lr: 1.0000e-04
# Epoch 29/90
# 9/9 [==============================] - 9s 945ms/step - loss: 0.0155 - categorical_accuracy: 0.9923 - val_loss: 0.1445 - val_categorical_accuracy: 0.9091 - lr: 1.0000e-04
# Epoch 29: early stopping

# %%
df_y_test = to_categorical(y_test,num_classes=num_classes)

val_loss, val_acc = model.evaluate(x_test,df_y_test)
print(val_loss, val_acc)
# Out:
# 3/3 [==============================] - 1s 204ms/step - loss: 0.1620 - categorical_accuracy: 0.9268
# 0.16198712587356567 0.9268292784690857

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis=1)

#print(y_pred[0:50])

out_acc = accuracy_score(y_test, y_pred)
out_f1 = f1_score(y_test, y_pred,average ='micro')

print("Accuracy: {}".format(round(out_acc,4)))
print("F1 Score(micro): {}".format(round(out_f1,4)))

out_f1 = f1_score(y_test, y_pred,average ='macro')
print("F1 Score(macro): {}".format(round(out_f1,4)))

out_f1 = f1_score(y_test, y_pred,average ='weighted')
print("F1 Score(weighted): {}".format(round(out_f1,4)))
# Out:
# 3/3 [==============================] - 1s 210ms/step
# Accuracy: 0.9268
# F1 Score(micro): 0.9268
# F1 Score(macro): 0.9152
# F1 Score(weighted): 0.9253
