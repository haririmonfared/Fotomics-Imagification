# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from keras.models import Model
from keras.layers import Input, Activation, Concatenate
from keras.layers import Flatten, Dropout
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import GlobalAveragePooling2D

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical

# %%
# change data format 

from keras import backend as K  
print(K.image_data_format()) 
K.set_image_data_format('channels_last')   
print(K.image_data_format())
# Out:
# channels_last
# channels_last

# %%
x_train = np.load('/content/drive/MyDrive/USYD/2021 S1/INFO4001/deepinsight_shuffle_img/x_train_img.npy') 
x_test = np.load('/content/drive/MyDrive/USYD/2021 S1/INFO4001/deepinsight_shuffle_img/x_test_img.npy')

# modify the default parameters of np.load



y_train = np.load('/content/drive/MyDrive/USYD/2021 S1/INFO4001/deepinsight_shuffle_img/y_train_img.npy',allow_pickle=True)
y_test = np.load('/content/drive/MyDrive/USYD/2021 S1/INFO4001/deepinsight_shuffle_img/y_test_img.npy',allow_pickle=True)

# %%
label = ['16cell','2cell','4cell','8cell','blast','zygote']

n_lst=[]
for i in range(len(y_train)):
  for j in range(len(label)):
    if y_train[i] == label[j]:

      n_lst.append(j)

y_new_train = np.array(n_lst,dtype='float64')

n_lst=[]
for i in range(len(y_test)):
  for j in range(len(label)):
    if y_test[i] == label[j]:
      n_lst.append(j)

y_new_test = np.array(n_lst,dtype='float64')

# %%
df_y_train = to_categorical(y_new_train,num_classes=6)

# %%
x_train[0].shape
# Out:
# (50, 50, 3)

# %%
def SqueezeNet(nb_classes, inputs=(50, 50, 3)):
    """ Keras Implementation of SqueezeNet(arXiv 1602.07360)
    @param nb_classes: total number of final categories
    Arguments:
    inputs -- shape of the input images (channel, cols, rows)
    """

    input_img = Input(shape=inputs)
    conv1 = Convolution2D(
        96, (7, 7), activation='relu', kernel_initializer='glorot_uniform',
        strides=(2, 2), padding='same', name='conv1',
        data_format="channels_last")(input_img)
    maxpool1 = MaxPooling2D(
        pool_size=(3, 3), strides=(2, 2), name='maxpool1',
        data_format="channels_last")(conv1)
    fire2_squeeze = Convolution2D(
        16, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire2_squeeze',
        data_format="channels_last")(maxpool1)
    fire2_expand1 = Convolution2D(
        64, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire2_expand1',
        data_format="channels_last")(fire2_squeeze)
    fire2_expand2 = Convolution2D(
        64, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire2_expand2',
        data_format="channels_last")(fire2_squeeze)
    merge2 = Concatenate(axis=1)([fire2_expand1, fire2_expand2])

    fire3_squeeze = Convolution2D(
        16, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire3_squeeze',
        data_format="channels_last")(merge2)
    fire3_expand1 = Convolution2D(
        64, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire3_expand1',
        data_format="channels_last")(fire3_squeeze)
    fire3_expand2 = Convolution2D(
        64, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire3_expand2',
        data_format="channels_last")(fire3_squeeze)
    merge3 = Concatenate(axis=1)([fire3_expand1, fire3_expand2])

    fire4_squeeze = Convolution2D(
        32, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire4_squeeze',
        data_format="channels_last")(merge3)
    fire4_expand1 = Convolution2D(
        128, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire4_expand1',
        data_format="channels_last")(fire4_squeeze)
    fire4_expand2 = Convolution2D(
        128, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire4_expand2',
        data_format="channels_last")(fire4_squeeze)
    merge4 = Concatenate(axis=1)([fire4_expand1, fire4_expand2])
    maxpool4 = MaxPooling2D(
        pool_size=(3, 3), strides=(2, 2), name='maxpool4',
        data_format="channels_last")(merge4)

    fire5_squeeze = Convolution2D(
        32, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire5_squeeze',
        data_format="channels_last")(maxpool4)
    fire5_expand1 = Convolution2D(
        128, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire5_expand1',
        data_format="channels_last")(fire5_squeeze)
    fire5_expand2 = Convolution2D(
        128, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire5_expand2',
        data_format="channels_last")(fire5_squeeze)
    merge5 = Concatenate(axis=1)([fire5_expand1, fire5_expand2])

    fire6_squeeze = Convolution2D(
        48, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire6_squeeze',
        data_format="channels_last")(merge5)
    fire6_expand1 = Convolution2D(
        192, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire6_expand1',
        data_format="channels_last")(fire6_squeeze)
    fire6_expand2 = Convolution2D(
        192, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire6_expand2',
        data_format="channels_last")(fire6_squeeze)
    merge6 = Concatenate(axis=1)([fire6_expand1, fire6_expand2])

    fire7_squeeze = Convolution2D(
        48, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire7_squeeze',
        data_format="channels_last")(merge6)
    fire7_expand1 = Convolution2D(
        192, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire7_expand1',
        data_format="channels_last")(fire7_squeeze)
    fire7_expand2 = Convolution2D(
        192, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire7_expand2',
        data_format="channels_last")(fire7_squeeze)
    merge7 = Concatenate(axis=1)([fire7_expand1, fire7_expand2])

    fire8_squeeze = Convolution2D(
        64, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire8_squeeze',
        data_format="channels_last")(merge7)
    fire8_expand1 = Convolution2D(
        256, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire8_expand1',
        data_format="channels_last")(fire8_squeeze)
    fire8_expand2 = Convolution2D(
        256, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire8_expand2',
        data_format="channels_last")(fire8_squeeze)
    merge8 = Concatenate(axis=1)([fire8_expand1, fire8_expand2])

    maxpool8 = MaxPooling2D(
        pool_size=(3, 3), strides=(2, 2), name='maxpool8',
        data_format="channels_last")(merge8)
    fire9_squeeze = Convolution2D(
        64, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire9_squeeze',
        data_format="channels_last")(maxpool8)
    fire9_expand1 = Convolution2D(
        256, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire9_expand1',
        data_format="channels_last")(fire9_squeeze)
    fire9_expand2 = Convolution2D(
        256, (3, 3), activation='relu', kernel_initializer='glorot_uniform',
        padding='same', name='fire9_expand2',
        data_format="channels_last")(fire9_squeeze)
    merge9 = Concatenate(axis=1)([fire9_expand1, fire9_expand2])

    fire9_dropout = Dropout(0.5, name='fire9_dropout')(merge9)
    conv10 = Convolution2D(
        nb_classes, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='valid', name='conv10',
        data_format="channels_last")(fire9_dropout)

    global_avgpool10 = GlobalAveragePooling2D(data_format='channels_last')(conv10)
    softmax = Activation("softmax", name='softmax')(global_avgpool10)

    return Model(inputs=input_img, outputs=softmax)

# %%
my_model = SqueezeNet(6)

# %%
my_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
print(x_train.shape)

x_ed_train = np.transpose(x_train, (0, 3, 1, 2))

print(x_ed_train.shape)
# Out:
# (214, 50, 50, 3)
# (214, 3, 50, 50)

# %%
# Out:
# channels_first
# channels_first

# %%
my_model.fit(x_train,df_y_train, batch_size=32, epochs=90, validation_split=0.2)
# Out:
# Epoch 1/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.8209 - accuracy: 0.6433 - val_loss: 0.8318 - val_accuracy: 0.6279
# Epoch 2/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.6789 - accuracy: 0.6842 - val_loss: 0.5472 - val_accuracy: 0.6977
# Epoch 3/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.5583 - accuracy: 0.7485 - val_loss: 0.4390 - val_accuracy: 0.8372
# Epoch 4/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.5249 - accuracy: 0.7719 - val_loss: 0.3591 - val_accuracy: 0.8605
# Epoch 5/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.4071 - accuracy: 0.8070 - val_loss: 0.4333 - val_accuracy: 0.7907
# Epoch 6/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3901 - accuracy: 0.8129 - val_loss: 0.3397 - val_accuracy: 0.7907
# Epoch 7/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3952 - accuracy: 0.8304 - val_loss: 0.3799 - val_accuracy: 0.8140
# Epoch 8/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2945 - accuracy: 0.8713 - val_loss: 0.4327 - val_accuracy: 0.8605
# Epoch 9/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.4113 - accuracy: 0.8246 - val_loss: 0.4621 - val_accuracy: 0.7907
# Epoch 10/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.8054 - accuracy: 0.6433 - val_loss: 0.5949 - val_accuracy: 0.6977
# Epoch 11/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.6457 - accuracy: 0.6842 - val_loss: 0.6898 - val_accuracy: 0.6744
# Epoch 12/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.5128 - accuracy: 0.8304 - val_loss: 0.3721 - val_accuracy: 0.8605
# Epoch 13/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3324 - accuracy: 0.8713 - val_loss: 0.2951 - val_accuracy: 0.8837
# Epoch 14/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2826 - accuracy: 0.8713 - val_loss: 0.3504 - val_accuracy: 0.8140
# Epoch 15/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.4811 - accuracy: 0.8012 - val_loss: 0.5236 - val_accuracy: 0.7442
# Epoch 16/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3775 - accuracy: 0.8421 - val_loss: 0.4669 - val_accuracy: 0.8140
# Epoch 17/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3407 - accuracy: 0.8421 - val_loss: 0.3934 - val_accuracy: 0.8372
# Epoch 18/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3799 - accuracy: 0.8246 - val_loss: 0.4239 - val_accuracy: 0.7907
# Epoch 19/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3956 - accuracy: 0.8129 - val_loss: 0.3821 - val_accuracy: 0.8140
# Epoch 20/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2946 - accuracy: 0.8655 - val_loss: 0.3122 - val_accuracy: 0.8605
# Epoch 21/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2407 - accuracy: 0.9181 - val_loss: 0.2873 - val_accuracy: 0.8837
# Epoch 22/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1917 - accuracy: 0.9298 - val_loss: 0.2323 - val_accuracy: 0.9070
# Epoch 23/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2059 - accuracy: 0.8713 - val_loss: 0.2350 - val_accuracy: 0.8372
# Epoch 24/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1501 - accuracy: 0.9474 - val_loss: 0.3109 - val_accuracy: 0.8605
# Epoch 25/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1446 - accuracy: 0.9357 - val_loss: 0.6965 - val_accuracy: 0.7674
# Epoch 26/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3497 - accuracy: 0.8596 - val_loss: 4.3371 - val_accuracy: 0.2558
# Epoch 27/90
# 6/6 [==============================] - 18s 3s/step - loss: 2.1258 - accuracy: 0.5906 - val_loss: 0.8303 - val_accuracy: 0.6512
# Epoch 28/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.9849 - accuracy: 0.5789 - val_loss: 1.1070 - val_accuracy: 0.4884
# Epoch 29/90
# 6/6 [==============================] - 18s 3s/step - loss: 1.0043 - accuracy: 0.4854 - val_loss: 0.9168 - val_accuracy: 0.5349
# Epoch 30/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.8713 - accuracy: 0.5322 - val_loss: 0.8000 - val_accuracy: 0.6047
# Epoch 31/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.7829 - accuracy: 0.6433 - val_loss: 0.7368 - val_accuracy: 0.5814
# Epoch 32/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.6590 - accuracy: 0.7310 - val_loss: 0.5852 - val_accuracy: 0.7907
# Epoch 33/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.5220 - accuracy: 0.7953 - val_loss: 0.4223 - val_accuracy: 0.8372
# Epoch 34/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.4688 - accuracy: 0.7895 - val_loss: 0.4556 - val_accuracy: 0.7442
# Epoch 35/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.3962 - accuracy: 0.8187 - val_loss: 0.4201 - val_accuracy: 0.7907
# Epoch 36/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.3077 - accuracy: 0.8713 - val_loss: 0.3713 - val_accuracy: 0.8140
# Epoch 37/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.3007 - accuracy: 0.8304 - val_loss: 0.4164 - val_accuracy: 0.8140
# Epoch 38/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.3389 - accuracy: 0.8421 - val_loss: 0.5859 - val_accuracy: 0.6744
# Epoch 39/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.5704 - accuracy: 0.7193 - val_loss: 0.5123 - val_accuracy: 0.7674
# Epoch 40/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3545 - accuracy: 0.8655 - val_loss: 0.3375 - val_accuracy: 0.8837
# Epoch 41/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3308 - accuracy: 0.8596 - val_loss: 0.3546 - val_accuracy: 0.8140
# Epoch 42/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2988 - accuracy: 0.8655 - val_loss: 0.4541 - val_accuracy: 0.7674
# Epoch 43/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2876 - accuracy: 0.8596 - val_loss: 0.2536 - val_accuracy: 0.8605
# Epoch 44/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2669 - accuracy: 0.9064 - val_loss: 0.3157 - val_accuracy: 0.8605
# Epoch 45/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.2465 - accuracy: 0.8947 - val_loss: 0.2710 - val_accuracy: 0.8837
# Epoch 46/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1869 - accuracy: 0.9357 - val_loss: 0.3721 - val_accuracy: 0.8837
# Epoch 47/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1910 - accuracy: 0.9298 - val_loss: 0.3886 - val_accuracy: 0.7907
# Epoch 48/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2043 - accuracy: 0.9240 - val_loss: 0.2355 - val_accuracy: 0.8837
# Epoch 49/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.1544 - accuracy: 0.9298 - val_loss: 0.3306 - val_accuracy: 0.8605
# Epoch 50/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.1440 - accuracy: 0.9357 - val_loss: 0.3017 - val_accuracy: 0.8140
# Epoch 51/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.1253 - accuracy: 0.9415 - val_loss: 0.2837 - val_accuracy: 0.8605
# Epoch 52/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.1436 - accuracy: 0.9357 - val_loss: 0.3049 - val_accuracy: 0.8837
# Epoch 53/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.0995 - accuracy: 0.9942 - val_loss: 0.3158 - val_accuracy: 0.9535
# Epoch 54/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0873 - accuracy: 0.9766 - val_loss: 0.3625 - val_accuracy: 0.8140
# Epoch 55/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1016 - accuracy: 0.9708 - val_loss: 0.3841 - val_accuracy: 0.8372
# Epoch 56/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.4239 - accuracy: 0.8538 - val_loss: 1.2877 - val_accuracy: 0.6047
# Epoch 57/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.5817 - accuracy: 0.7602 - val_loss: 0.5631 - val_accuracy: 0.7674
# Epoch 58/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.7211 - accuracy: 0.6901 - val_loss: 0.6524 - val_accuracy: 0.6744
# Epoch 59/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.6774 - accuracy: 0.6550 - val_loss: 0.6588 - val_accuracy: 0.6977
# Epoch 60/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.5820 - accuracy: 0.7310 - val_loss: 0.5450 - val_accuracy: 0.7674
# Epoch 61/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.4732 - accuracy: 0.8713 - val_loss: 0.4156 - val_accuracy: 0.8140
# Epoch 62/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.3436 - accuracy: 0.8538 - val_loss: 0.4887 - val_accuracy: 0.7674
# Epoch 63/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.2607 - accuracy: 0.8830 - val_loss: 0.4316 - val_accuracy: 0.8140
# Epoch 64/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1851 - accuracy: 0.9357 - val_loss: 0.3606 - val_accuracy: 0.7674
# Epoch 65/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1460 - accuracy: 0.9298 - val_loss: 0.1885 - val_accuracy: 0.8837
# Epoch 66/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1709 - accuracy: 0.9064 - val_loss: 0.2085 - val_accuracy: 0.8837
# Epoch 67/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1253 - accuracy: 0.9532 - val_loss: 0.4725 - val_accuracy: 0.8605
# Epoch 68/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1223 - accuracy: 0.9591 - val_loss: 0.2517 - val_accuracy: 0.8837
# Epoch 69/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0920 - accuracy: 0.9649 - val_loss: 0.3492 - val_accuracy: 0.8837
# Epoch 70/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.1064 - accuracy: 0.9591 - val_loss: 0.3331 - val_accuracy: 0.8140
# Epoch 71/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1626 - accuracy: 0.9357 - val_loss: 0.5123 - val_accuracy: 0.8372
# Epoch 72/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1615 - accuracy: 0.9474 - val_loss: 0.1900 - val_accuracy: 0.8605
# Epoch 73/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.1093 - accuracy: 0.9357 - val_loss: 0.1971 - val_accuracy: 0.9070
# Epoch 74/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0799 - accuracy: 0.9591 - val_loss: 0.3241 - val_accuracy: 0.8837
# Epoch 75/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0777 - accuracy: 0.9649 - val_loss: 0.2284 - val_accuracy: 0.9535
# Epoch 76/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9535
# Epoch 77/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0419 - accuracy: 0.9883 - val_loss: 0.1658 - val_accuracy: 0.9767
# Epoch 78/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.8605
# Epoch 79/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0561 - accuracy: 0.9708 - val_loss: 0.3725 - val_accuracy: 0.8837
# Epoch 80/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0472 - accuracy: 0.9708 - val_loss: 0.2233 - val_accuracy: 0.9535
# Epoch 81/90
# 6/6 [==============================] - 17s 3s/step - loss: 0.0233 - accuracy: 0.9942 - val_loss: 0.1983 - val_accuracy: 0.9767
# Epoch 82/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0137 - accuracy: 0.9942 - val_loss: 0.1655 - val_accuracy: 0.9767
# Epoch 83/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9535
# Epoch 84/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9535
# Epoch 85/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9767
# Epoch 86/90
# 6/6 [==============================] - 18s 3s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9767
# Epoch 87/90
# 6/6 [==============================] - 18s 3s/step - loss: 5.1828e-04 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9767
# Epoch 88/90
# 6/6 [==============================] - 18s 3s/step - loss: 9.6586e-04 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9767
# Epoch 89/90
# 6/6 [==============================] - 18s 3s/step - loss: 3.0842e-04 - accuracy: 1.0000 - val_loss: 0.1719 - val_accuracy: 0.9767
# Epoch 90/90
# 6/6 [==============================] - 18s 3s/step - loss: 2.2341e-04 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9767

# %%
df_y_test = to_categorical(y_new_test,num_classes=6)

# %%
val_loss, val_acc = my_model.evaluate(x_test,df_y_test)
print(val_loss, val_acc)
# Out:
# 2/2 [==============================] - 1s 585ms/step - loss: 0.7035 - accuracy: 0.9259
# 0.7035230994224548 0.9259259104728699
