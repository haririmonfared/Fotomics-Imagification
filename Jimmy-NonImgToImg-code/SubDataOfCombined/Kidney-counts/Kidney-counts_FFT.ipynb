# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
from scipy.spatial import ConvexHull
from matplotlib import pyplot as plt
import inspect
from numpy.fft import fft
from numpy.fft import fftshift


class LogScaler:
    #Log normalization and data scaling
    
    def __init__(self):
        self._min0 = None
        self._max = None
        pass

    def fit(self, X, y=None):
        self._min0 = X.min(axis=0)
        self._max = np.log(X + np.abs(self._min0) + 1).max()

    def fit_transform(self, X, y=None):
        self._min0 = X.min(axis=0)
        X_norm = np.log(X + np.abs(self._min0) + 1)
        self._max = X_norm.max()
        return X_norm / self._max

    def transform(self, X, y=None):
        X_norm = np.log(X + np.abs(self._min0) + 1).clip(0, None)
        return (X_norm / self._max).clip(0, 1)


class FftTransformer:
    # Image transformer based on fast fourier transform

    def __init__(self, pixels=124):
        if isinstance(pixels, int):
            pixels = (pixels, pixels)
        self._pixels = pixels
        self._xrot = None

    def fft_fit(self,X):     
        z1_lst=[]
        z2_lst=[]

        for cur_x in range(len(X)):
            x_ft = fftshift(fft(X[cur_x]))
                 
            real_lst =[0]*len(x_ft)
            imag_lst= [0]*len(x_ft)

            for i in range(len(x_ft)):
                real_lst[i] = x_ft[i].real
                imag_lst[i] = x_ft[i].imag

            q1, q3 = np.percentile(sorted(real_lst), [10, 90])
            iqr = q3 - q1
    
            # find lower and upper bounds
            lower_bound = q1 - (1.5 * iqr)
            upper_bound = q3 + (1.5 * iqr)

            outliers=[]
            outliers_idx=[]
            for i in range(len(real_lst)):
                if real_lst[i] <= lower_bound or real_lst[i] >= upper_bound:
                    outliers.append(real_lst[i])
                    outliers_idx.append(i)
            
            for i in range(len(outliers_idx)):
                real_lst[outliers_idx[i]]=0
            
            # imag 
            q1, q3 = np.percentile(sorted(imag_lst), [10, 90])
            iqr = q3 - q1
    
            # find lower and upper bounds
            lower_bound = q1 - (1.5 * iqr)
            upper_bound = q3 + (1.5 * iqr)

            outliers=[]
            outliers_idx=[]
            for i in range(len(imag_lst)):
                if imag_lst[i] <= lower_bound or imag_lst[i] >= upper_bound:
                    outliers.append(imag_lst[i])
                    outliers_idx.append(i)
            
            for i in range(len(outliers_idx)):
                imag_lst[outliers_idx[i]]=0

            z1_lst.append(np.array(real_lst))
            z2_lst.append(np.array(imag_lst))
    
        z1_lst = np.mean(np.array(z1_lst),axis=0) 
        z2_lst = np.mean(np.array(z2_lst),axis=0)

        real_mt = np.empty(shape=(x_ft.shape[0],1))
        real_mt.fill(0)
        imag_mt = np.empty(shape=(x_ft.shape[0],1))
        imag_mt.fill(0)

        for i in range(len(x_ft)):
            cur_real = z1_lst[i]
            real_mt[i] = cur_real

            cur_imag = z2_lst[i]
            imag_mt[i] = cur_imag

        z1 = real_mt
        z2 = imag_mt
        full_mt = np.hstack((z1,z2))
    
        return full_mt

    def fit(self, X, y=None, plot=False):
        x_new = self.fft_fit(X)        

        # get the convex hull for the points
        chvertices = ConvexHull(x_new).vertices

        hull_points = x_new[chvertices]

        # get minimum bounding rectangle
        mbr, mbr_rot = self._minimum_bounding_rectangle(hull_points)
        
        # matrix rotation
        self._xrot = np.dot(mbr_rot, x_new.T).T
        
        # get feature coordinates from pixel dimension
        self._calculate_coords()

        #  rotation diagram plot
        if plot is True:
            plt.scatter(x_new[:, 0], x_new[:, 1], s=1,
                        cmap=plt.cm.get_cmap("jet", 10), alpha=0.2)
            plt.fill(x_new[chvertices, 0], x_new[chvertices, 1],
                     edgecolor='r', fill=False)
            plt.fill(mbr[:, 0], mbr[:, 1], edgecolor='g', fill=False)
            plt.gca().set_aspect('equal', adjustable='box')
            plt.show()
        return self

    @property
    def pixels(self):
        # Image matrix dimensions
        # Returns:
        #     tuples: (height, width)

        return self._pixels

    @pixels.setter
    def pixels(self, pixels):
        # set image matrix dimension

        if isinstance(pixels, int):
            pixels = (pixels, pixels)
        self._pixels = pixels
        # recalculate coordinates if already fit
        if hasattr(self, '_coords'):
            self._calculate_coords()

    def _calculate_coords(self):

        # Calculate matrix coordinates of each feature based on the pixel dimensions


        cur_xrp = self._xrot[:, 0]
        cur_yrp = self._xrot[:, 1] 

        ax0_coord = np.digitize(
            cur_xrp,
            bins=np.linspace(min(cur_xrp), max(cur_xrp),
                             self._pixels[0])
        ) - 1
        ax1_coord = np.digitize(
            cur_yrp,
            bins=np.linspace(min(cur_yrp), max(cur_yrp),
                             self._pixels[1])
        ) - 1

        self._coords = np.stack((ax0_coord, ax1_coord), axis=1)

    def transform(self, X):
 
        img_coords = pd.DataFrame(np.vstack((
            self._coords.T,
            X
        )).T).groupby([0, 1], as_index=False).mean()

        img_matrices = []
        blank_mat = np.zeros(self._pixels)
        
        for z in range(2, img_coords.shape[1]):
            img_matrix = blank_mat.copy()
            img_matrix[img_coords[0].astype(int),
                       img_coords[1].astype(int)] = img_coords[z]
            img_matrices.append(img_matrix)

    
        img_matrices = np.array([self._mat_to_rgb(m) for m in img_matrices])
        
        return img_matrices

    def fit_transform(self, X, **kwargs):

        self.fit(X)
        return self.transform(X, **kwargs)

    def feature_density_matrix(self):

        fdmat = np.zeros(self._pixels)
        np.add.at(fdmat, tuple(self._coords.T), 1)
        return fdmat

    def coords(self):
        #Get feature coordinates

        return self._coords.copy()

    @staticmethod
    def _minimum_bounding_rectangle(hull_points):
        """Find the smallest bounding rectangle for a set of points.
        Modified from JesseBuesking at https://stackoverflow.com/a/33619018
        Returns a set of points representing the corners of the bounding box.
        Args:
            hull_points : an nx2 matrix of hull coordinates
        Returns:
            (tuple): tuple containing
                coords (ndarray): coordinates of the corners of the rectangle
                rotmat (ndarray): rotation matrix to align edges of rectangle
                    to x and y
        """

        pi2 = np.pi / 2
        # calculate edge angles
        edges = hull_points[1:] - hull_points[:-1]
        angles = np.arctan2(edges[:, 1], edges[:, 0])
        angles = np.abs(np.mod(angles, pi2))
        angles = np.unique(angles)
        # find rotation matrices
        rotations = np.vstack([
            np.cos(angles),
            -np.sin(angles),
            np.sin(angles),
            np.cos(angles)]).T
        rotations = rotations.reshape((-1, 2, 2))
        # apply rotations to the hull
        rot_points = np.dot(rotations, hull_points.T)
        # find the bounding points
        min_x = np.nanmin(rot_points[:, 0], axis=1)
        max_x = np.nanmax(rot_points[:, 0], axis=1)
        min_y = np.nanmin(rot_points[:, 1], axis=1)
        max_y = np.nanmax(rot_points[:, 1], axis=1)
        # find the box with the best area
        areas = (max_x - min_x) * (max_y - min_y)
        best_idx = np.argmin(areas)
        # return the best box
        x1 = max_x[best_idx]
        x2 = min_x[best_idx]
        y1 = max_y[best_idx]
        y2 = min_y[best_idx]
        rotmat = rotations[best_idx]
        # generate coordinates
        coords = np.zeros((4, 2))
        coords[0] = np.dot([x1, y2], rotmat)
        coords[1] = np.dot([x2, y2], rotmat)
        coords[2] = np.dot([x2, y1], rotmat)
        coords[3] = np.dot([x1, y1], rotmat)

        return coords, rotmat

    @staticmethod
    def _mat_to_rgb(mat):
        """Convert image matrix to numpy rgb format
        Args:
            mat: {array-like} (M, N)
        Returns:
            An numpy.ndarry (M, N, 3) with orignal values repeated across
            RGB channels.
        """
        return np.repeat(mat[:, :, np.newaxis], 3, axis=2)

# %%
import h5py

# %%
h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Kidney-counts_x_train.h5','r')
x_train = h5f['dataset_1'][:]
h5f.close()


h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Kidney-counts_x_test.h5','r')
x_test = h5f['dataset_1'][:]
h5f.close()

h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Kidney-counts_y_train.h5','r')
y_train = h5f['dataset_1'][:]
h5f.close()

h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Kidney-counts_y_test.h5','r')
y_test = h5f['dataset_1'][:]
h5f.close()

# %%
x_train.shape
# Out:
# (415, 23433)

# %%
x_test.shape
# Out:
# (104, 23433)

# %%
y_train.shape
# Out:
# (415,)

# %%
y_test.shape
# Out:
# (104,)

# %%
x_train = np.nan_to_num(x_train)
x_test = np.nan_to_num(x_test)
sum_train = np.sum(x_train,axis=1)
sum_train = sum_train.reshape(sum_train.shape[0],-1)
sum_test = np.sum(x_test,axis=1)
sum_test = sum_test.reshape(sum_test.shape[0],-1)


x_train = np.divide(x_train, sum_train)
x_test =  np.divide(x_test, sum_test)
print(x_train.shape)
# Out:
# (415, 23433)

# %%
import gc

del sum_train
del sum_test

gc.collect()
# Out:
# 66

# %%
ln = LogScaler()

x_train = ln.fit_transform(x_train)
x_test = ln.transform(x_test)

# %%
it = FftTransformer(pixels=124)
_ = it.fit(x_train, plot=True)

# %%
del _
gc.collect()
# Out:
# 2356

# %%
x_train = it.transform(x_train)
x_train.shape
# Out:
# (415, 124, 124, 3)

# %%
x_test = it.transform(x_test)
x_test.shape
# Out:
# (104, 124, 124, 3)

# %%
print("Train img")
plt.figure(figsize=(15,4))

#subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(1,10,figsize=(30,30)) 

for i in range(10):
    axarr[i].imshow(x_train[i])
    print(y_train[i])
# Out:
# Train img
# 1.0
# 0.0
# 1.0
# 4.0
# 2.0
# 2.0
# 3.0
# 2.0
# 1.0
# 1.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from keras import layers

# %%
unique_classes = np.unique(y_train)

# %%
num_classes = len(unique_classes)
print(num_classes)
# Out:
# 5

# %%
df_y_train = to_categorical(y_train,num_classes=num_classes)

# %%
print(x_train.shape)
print(df_y_train.shape)
# Out:
# (415, 124, 124, 3)
# (415, 5)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint , ReduceLROnPlateau


model = Sequential()
model.add(Conv2D(64,(3,3),input_shape=(124,124,3)) )
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3) ))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64))
model.add(Dense(num_classes))
model.add(Activation('sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['categorical_accuracy'])

earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
mcp_save = ModelCheckpoint('.mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='auto')
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, verbose=1, min_delta=1e-4, mode='auto')

model.fit(x_train, df_y_train, batch_size=32, epochs=90, verbose=1, callbacks=[earlyStopping, mcp_save, reduce_lr_loss], validation_split=0.2)
# Out:
# Epoch 1/90
# 11/11 [==============================] - 14s 1s/step - loss: 0.5153 - categorical_accuracy: 0.4217 - val_loss: 0.4367 - val_categorical_accuracy: 0.4217 - lr: 0.0010
# Epoch 2/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.4282 - categorical_accuracy: 0.4217 - val_loss: 0.4187 - val_categorical_accuracy: 0.4337 - lr: 0.0010
# Epoch 3/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.4104 - categorical_accuracy: 0.4337 - val_loss: 0.4105 - val_categorical_accuracy: 0.5301 - lr: 0.0010
# Epoch 4/90
# 11/11 [==============================] - 14s 1s/step - loss: 0.4006 - categorical_accuracy: 0.4548 - val_loss: 0.3929 - val_categorical_accuracy: 0.5663 - lr: 0.0010
# Epoch 5/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.3870 - categorical_accuracy: 0.4880 - val_loss: 0.3707 - val_categorical_accuracy: 0.5663 - lr: 0.0010
# Epoch 6/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.3694 - categorical_accuracy: 0.5271 - val_loss: 0.3702 - val_categorical_accuracy: 0.5904 - lr: 0.0010
# Epoch 7/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.3554 - categorical_accuracy: 0.5693 - val_loss: 0.3343 - val_categorical_accuracy: 0.6386 - lr: 0.0010
# Epoch 8/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.3044 - categorical_accuracy: 0.6988 - val_loss: 0.2529 - val_categorical_accuracy: 0.8193 - lr: 0.0010
# Epoch 9/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.2451 - categorical_accuracy: 0.7982 - val_loss: 0.1960 - val_categorical_accuracy: 0.8554 - lr: 0.0010
# Epoch 10/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.1990 - categorical_accuracy: 0.8283 - val_loss: 0.1454 - val_categorical_accuracy: 0.9157 - lr: 0.0010
# Epoch 11/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.1421 - categorical_accuracy: 0.9247 - val_loss: 0.1256 - val_categorical_accuracy: 0.9036 - lr: 0.0010
# Epoch 12/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.1206 - categorical_accuracy: 0.9157 - val_loss: 0.0831 - val_categorical_accuracy: 0.9398 - lr: 0.0010
# Epoch 13/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0935 - categorical_accuracy: 0.9428 - val_loss: 0.0596 - val_categorical_accuracy: 0.9518 - lr: 0.0010
# Epoch 14/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0738 - categorical_accuracy: 0.9518 - val_loss: 0.0536 - val_categorical_accuracy: 0.9759 - lr: 0.0010
# Epoch 15/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0642 - categorical_accuracy: 0.9608 - val_loss: 0.0581 - val_categorical_accuracy: 0.9639 - lr: 0.0010
# Epoch 16/90
# 11/11 [==============================] - 15s 1s/step - loss: 0.0787 - categorical_accuracy: 0.9639 - val_loss: 0.0512 - val_categorical_accuracy: 0.9639 - lr: 0.0010
# Epoch 17/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0637 - categorical_accuracy: 0.9578 - val_loss: 0.0422 - val_categorical_accuracy: 0.9639 - lr: 0.0010
# Epoch 18/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0533 - categorical_accuracy: 0.9608 - val_loss: 0.0304 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0437 - categorical_accuracy: 0.9608 - val_loss: 0.0290 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0341 - categorical_accuracy: 0.9940 - val_loss: 0.0278 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0273 - categorical_accuracy: 0.9849 - val_loss: 0.0220 - val_categorical_accuracy: 0.9880 - lr: 0.0010
# Epoch 22/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0234 - categorical_accuracy: 0.9940 - val_loss: 0.0191 - val_categorical_accuracy: 0.9880 - lr: 0.0010
# Epoch 23/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0212 - categorical_accuracy: 0.9970 - val_loss: 0.0203 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0219 - categorical_accuracy: 0.9910 - val_loss: 0.0288 - val_categorical_accuracy: 0.9759 - lr: 0.0010
# Epoch 25/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0194 - categorical_accuracy: 0.9910 - val_loss: 0.0169 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0160 - categorical_accuracy: 0.9910 - val_loss: 0.0186 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0162 - categorical_accuracy: 1.0000 - val_loss: 0.0153 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0113 - categorical_accuracy: 0.9970 - val_loss: 0.0223 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0128 - categorical_accuracy: 1.0000 - val_loss: 0.0179 - val_categorical_accuracy: 0.9759 - lr: 0.0010
# Epoch 30/90
# 11/11 [==============================] - 15s 1s/step - loss: 0.0105 - categorical_accuracy: 0.9970 - val_loss: 0.0150 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 31/90
# 11/11 [==============================] - 13s 1s/step - loss: 0.0097 - categorical_accuracy: 1.0000 - val_loss: 0.0113 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 32/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0104 - categorical_accuracy: 1.0000 - val_loss: 0.0144 - val_categorical_accuracy: 0.9880 - lr: 0.0010
# Epoch 33/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0092 - categorical_accuracy: 1.0000 - val_loss: 0.0140 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 34/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0057 - categorical_accuracy: 1.0000 - val_loss: 0.0149 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 35/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0060 - categorical_accuracy: 1.0000 - val_loss: 0.0138 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 36/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0053 - categorical_accuracy: 1.0000 - val_loss: 0.0115 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 37/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0056 - categorical_accuracy: 1.0000 - val_loss: 0.0163 - val_categorical_accuracy: 0.9880 - lr: 0.0010
# Epoch 38/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0045 - categorical_accuracy: 1.0000 - val_loss: 0.0112 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 39/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0040 - categorical_accuracy: 1.0000 - val_loss: 0.0097 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 40/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 0.0129 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 41/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.0073 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 42/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.0200 - val_categorical_accuracy: 0.9880 - lr: 0.0010
# Epoch 43/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 0.0089 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 44/90
# 11/11 [==============================] - 14s 1s/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.0125 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 45/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.0096 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 46/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.0139 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 47/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.0084 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 48/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.0143 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 49/90
# 11/11 [==============================] - ETA: 0s - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 11/11 [==============================] - 12s 1s/step - loss: 0.0013 - categorical_accuracy: 1.0000 - val_loss: 0.0094 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 50/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 0.0091 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 51/90
# 11/11 [==============================] - 12s 1s/step - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 0.0099 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 51: early stopping

# %%
df_y_test = to_categorical(y_test,num_classes=num_classes)

val_loss, val_acc = model.evaluate(x_test,df_y_test)
print(val_loss, val_acc)
# Out:
# 4/4 [==============================] - 1s 214ms/step - loss: 0.0474 - categorical_accuracy: 0.9808
# 0.04743487387895584 0.9807692170143127

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis=1)

#print(y_pred[0:50])

out_acc = accuracy_score(y_test, y_pred)
out_f1 = f1_score(y_test, y_pred,average ='micro')

print("Accuracy: {}".format(round(out_acc,4)))
print("F1 Score(micro): {}".format(round(out_f1,4)))

out_f1 = f1_score(y_test, y_pred,average ='macro')
print("F1 Score(macro): {}".format(round(out_f1,4)))

out_f1 = f1_score(y_test, y_pred,average ='weighted')
print("F1 Score(weighted): {}".format(round(out_f1,4)))
# Out:
# 4/4 [==============================] - 1s 214ms/step
# Accuracy: 0.9808
# F1 Score(micro): 0.9808
# F1 Score(macro): 0.9497
# F1 Score(weighted): 0.9799
