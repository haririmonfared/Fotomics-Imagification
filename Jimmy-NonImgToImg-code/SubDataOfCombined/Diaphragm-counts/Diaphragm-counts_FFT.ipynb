# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
from scipy.spatial import ConvexHull
from matplotlib import pyplot as plt
import inspect
from numpy.fft import fft
from numpy.fft import fftshift


class LogScaler:
    #Log normalization and data scaling
    
    def __init__(self):
        self._min0 = None
        self._max = None
        pass

    def fit(self, X, y=None):
        self._min0 = X.min(axis=0)
        self._max = np.log(X + np.abs(self._min0) + 1).max()

    def fit_transform(self, X, y=None):
        self._min0 = X.min(axis=0)
        X_norm = np.log(X + np.abs(self._min0) + 1)
        self._max = X_norm.max()
        return X_norm / self._max

    def transform(self, X, y=None):
        X_norm = np.log(X + np.abs(self._min0) + 1).clip(0, None)
        return (X_norm / self._max).clip(0, 1)


class FftTransformer:
    # Image transformer based on fast fourier transform

    def __init__(self, pixels=124):
        if isinstance(pixels, int):
            pixels = (pixels, pixels)
        self._pixels = pixels
        self._xrot = None

    def fft_fit(self,X):     
        z1_lst=[]
        z2_lst=[]

        for cur_x in range(len(X)):
            x_ft = fftshift(fft(X[cur_x]))
                 
            real_lst =[0]*len(x_ft)
            imag_lst= [0]*len(x_ft)

            for i in range(len(x_ft)):
                real_lst[i] = x_ft[i].real
                imag_lst[i] = x_ft[i].imag

            q1, q3 = np.percentile(sorted(real_lst), [10, 90])
            iqr = q3 - q1
    
            # find lower and upper bounds
            lower_bound = q1 - (1.5 * iqr)
            upper_bound = q3 + (1.5 * iqr)

            outliers=[]
            outliers_idx=[]
            for i in range(len(real_lst)):
                if real_lst[i] <= lower_bound or real_lst[i] >= upper_bound:
                    outliers.append(real_lst[i])
                    outliers_idx.append(i)
            
            for i in range(len(outliers_idx)):
                real_lst[outliers_idx[i]]=0
            
            # imag 
            q1, q3 = np.percentile(sorted(imag_lst), [10, 90])
            iqr = q3 - q1
    
            # find lower and upper bounds
            lower_bound = q1 - (1.5 * iqr)
            upper_bound = q3 + (1.5 * iqr)

            outliers=[]
            outliers_idx=[]
            for i in range(len(imag_lst)):
                if imag_lst[i] <= lower_bound or imag_lst[i] >= upper_bound:
                    outliers.append(imag_lst[i])
                    outliers_idx.append(i)
            
            for i in range(len(outliers_idx)):
                imag_lst[outliers_idx[i]]=0

            z1_lst.append(np.array(real_lst))
            z2_lst.append(np.array(imag_lst))
    
        z1_lst = np.mean(np.array(z1_lst),axis=0) 
        z2_lst = np.mean(np.array(z2_lst),axis=0)

        real_mt = np.empty(shape=(x_ft.shape[0],1))
        real_mt.fill(0)
        imag_mt = np.empty(shape=(x_ft.shape[0],1))
        imag_mt.fill(0)

        for i in range(len(x_ft)):
            cur_real = z1_lst[i]
            real_mt[i] = cur_real

            cur_imag = z2_lst[i]
            imag_mt[i] = cur_imag

        z1 = real_mt
        z2 = imag_mt
        full_mt = np.hstack((z1,z2))
    
        return full_mt

    def fit(self, X, y=None, plot=False):
        x_new = self.fft_fit(X)        

        # get the convex hull for the points
        chvertices = ConvexHull(x_new).vertices

        hull_points = x_new[chvertices]

        # get minimum bounding rectangle
        mbr, mbr_rot = self._minimum_bounding_rectangle(hull_points)
        
        # matrix rotation
        self._xrot = np.dot(mbr_rot, x_new.T).T
        
        # get feature coordinates from pixel dimension
        self._calculate_coords()

        #  rotation diagram plot
        if plot is True:
            plt.scatter(x_new[:, 0], x_new[:, 1], s=1,
                        cmap=plt.cm.get_cmap("jet", 10), alpha=0.2)
            plt.fill(x_new[chvertices, 0], x_new[chvertices, 1],
                     edgecolor='r', fill=False)
            plt.fill(mbr[:, 0], mbr[:, 1], edgecolor='g', fill=False)
            plt.gca().set_aspect('equal', adjustable='box')
            plt.show()
        return self

    @property
    def pixels(self):
        # Image matrix dimensions
        # Returns:
        #     tuples: (height, width)

        return self._pixels

    @pixels.setter
    def pixels(self, pixels):
        # set image matrix dimension

        if isinstance(pixels, int):
            pixels = (pixels, pixels)
        self._pixels = pixels
        # recalculate coordinates if already fit
        if hasattr(self, '_coords'):
            self._calculate_coords()

    def _calculate_coords(self):

        # Calculate matrix coordinates of each feature based on the pixel dimensions


        cur_xrp = self._xrot[:, 0]
        cur_yrp = self._xrot[:, 1] 

        ax0_coord = np.digitize(
            cur_xrp,
            bins=np.linspace(min(cur_xrp), max(cur_xrp),
                             self._pixels[0])
        ) - 1
        ax1_coord = np.digitize(
            cur_yrp,
            bins=np.linspace(min(cur_yrp), max(cur_yrp),
                             self._pixels[1])
        ) - 1

        self._coords = np.stack((ax0_coord, ax1_coord), axis=1)

    def transform(self, X):
 
        img_coords = pd.DataFrame(np.vstack((
            self._coords.T,
            X
        )).T).groupby([0, 1], as_index=False).mean()

        img_matrices = []
        blank_mat = np.zeros(self._pixels)
        
        for z in range(2, img_coords.shape[1]):
            img_matrix = blank_mat.copy()
            img_matrix[img_coords[0].astype(int),
                       img_coords[1].astype(int)] = img_coords[z]
            img_matrices.append(img_matrix)

    
        img_matrices = np.array([self._mat_to_rgb(m) for m in img_matrices])
        
        return img_matrices

    def fit_transform(self, X, **kwargs):

        self.fit(X)
        return self.transform(X, **kwargs)

    def feature_density_matrix(self):

        fdmat = np.zeros(self._pixels)
        np.add.at(fdmat, tuple(self._coords.T), 1)
        return fdmat

    def coords(self):
        #Get feature coordinates

        return self._coords.copy()

    @staticmethod
    def _minimum_bounding_rectangle(hull_points):
        """Find the smallest bounding rectangle for a set of points.
        Modified from JesseBuesking at https://stackoverflow.com/a/33619018
        Returns a set of points representing the corners of the bounding box.
        Args:
            hull_points : an nx2 matrix of hull coordinates
        Returns:
            (tuple): tuple containing
                coords (ndarray): coordinates of the corners of the rectangle
                rotmat (ndarray): rotation matrix to align edges of rectangle
                    to x and y
        """

        pi2 = np.pi / 2
        # calculate edge angles
        edges = hull_points[1:] - hull_points[:-1]
        angles = np.arctan2(edges[:, 1], edges[:, 0])
        angles = np.abs(np.mod(angles, pi2))
        angles = np.unique(angles)
        # find rotation matrices
        rotations = np.vstack([
            np.cos(angles),
            -np.sin(angles),
            np.sin(angles),
            np.cos(angles)]).T
        rotations = rotations.reshape((-1, 2, 2))
        # apply rotations to the hull
        rot_points = np.dot(rotations, hull_points.T)
        # find the bounding points
        min_x = np.nanmin(rot_points[:, 0], axis=1)
        max_x = np.nanmax(rot_points[:, 0], axis=1)
        min_y = np.nanmin(rot_points[:, 1], axis=1)
        max_y = np.nanmax(rot_points[:, 1], axis=1)
        # find the box with the best area
        areas = (max_x - min_x) * (max_y - min_y)
        best_idx = np.argmin(areas)
        # return the best box
        x1 = max_x[best_idx]
        x2 = min_x[best_idx]
        y1 = max_y[best_idx]
        y2 = min_y[best_idx]
        rotmat = rotations[best_idx]
        # generate coordinates
        coords = np.zeros((4, 2))
        coords[0] = np.dot([x1, y2], rotmat)
        coords[1] = np.dot([x2, y2], rotmat)
        coords[2] = np.dot([x2, y1], rotmat)
        coords[3] = np.dot([x1, y1], rotmat)

        return coords, rotmat

    @staticmethod
    def _mat_to_rgb(mat):
        """Convert image matrix to numpy rgb format
        Args:
            mat: {array-like} (M, N)
        Returns:
            An numpy.ndarry (M, N, 3) with orignal values repeated across
            RGB channels.
        """
        return np.repeat(mat[:, :, np.newaxis], 3, axis=2)

# %%
import h5py

# %%
h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Diaphragm-counts_x_train.h5','r')
x_train = h5f['dataset_1'][:]
h5f.close()


h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Diaphragm-counts_x_test.h5','r')
x_test = h5f['dataset_1'][:]
h5f.close()

h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Diaphragm-counts_y_train.h5','r')
y_train = h5f['dataset_1'][:]
h5f.close()

h5f = h5py.File('/content/drive/MyDrive/combined/sorted_h5_data/Diaphragm-counts_y_test.h5','r')
y_test = h5f['dataset_1'][:]
h5f.close()

# %%
x_train.shape
# Out:
# (696, 23433)

# %%
x_test.shape
# Out:
# (174, 23433)

# %%
y_train.shape
# Out:
# (696,)

# %%
y_test.shape
# Out:
# (174,)

# %%
x_train = np.nan_to_num(x_train)
x_test = np.nan_to_num(x_test)
sum_train = np.sum(x_train,axis=1)
sum_train = sum_train.reshape(sum_train.shape[0],-1)
sum_test = np.sum(x_test,axis=1)
sum_test = sum_test.reshape(sum_test.shape[0],-1)


x_train = np.divide(x_train, sum_train)
x_test =  np.divide(x_test, sum_test)
print(x_train.shape)
# Out:
# (696, 23433)

# %%
import gc

del sum_train
del sum_test

gc.collect()
# Out:
# 132

# %%
ln = LogScaler()

x_train = ln.fit_transform(x_train)
x_test = ln.transform(x_test)

# %%
it = FftTransformer(pixels=124)
_ = it.fit(x_train, plot=True)

# %%
del _
gc.collect()
# Out:
# 2758

# %%
x_train = it.transform(x_train)
x_train.shape
# Out:
# (696, 124, 124, 3)

# %%
x_test = it.transform(x_test)
x_test.shape
# Out:
# (174, 124, 124, 3)

# %%
print("Train img")
plt.figure(figsize=(15,4))

#subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(1,10,figsize=(30,30)) 

for i in range(10):
    axarr[i].imshow(x_train[i])
    print(y_train[i])
# Out:
# Train img
# 4.0
# 4.0
# 4.0
# 3.0
# 4.0
# 3.0
# 3.0
# 4.0
# 0.0
# 4.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from keras import layers

# %%
unique_classes = np.unique(y_train)

# %%
num_classes = len(unique_classes)
print(num_classes)
# Out:
# 5

# %%
df_y_train = to_categorical(y_train,num_classes=num_classes)

# %%
print(x_train.shape)
print(df_y_train.shape)
# Out:
# (696, 124, 124, 3)
# (696, 5)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint , ReduceLROnPlateau


model = Sequential()
model.add(Conv2D(64,(3,3),input_shape=(124,124,3)) )
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3) ))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64))
model.add(Dense(num_classes))
model.add(Activation('sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['categorical_accuracy'])

earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
mcp_save = ModelCheckpoint('.mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='auto')
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, verbose=1, min_delta=1e-4, mode='auto')

model.fit(x_train, df_y_train, batch_size=32, epochs=90, verbose=1, callbacks=[earlyStopping, mcp_save, reduce_lr_loss], validation_split=0.2)
# Out:
# Epoch 1/90
# 18/18 [==============================] - 22s 1s/step - loss: 0.4739 - categorical_accuracy: 0.4766 - val_loss: 0.4160 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/90
# 18/18 [==============================] - 22s 1s/step - loss: 0.3996 - categorical_accuracy: 0.5072 - val_loss: 0.3798 - val_categorical_accuracy: 0.5143 - lr: 0.0010
# Epoch 3/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.3406 - categorical_accuracy: 0.5863 - val_loss: 0.2820 - val_categorical_accuracy: 0.7786 - lr: 0.0010
# Epoch 4/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.2112 - categorical_accuracy: 0.8435 - val_loss: 0.1186 - val_categorical_accuracy: 0.9071 - lr: 0.0010
# Epoch 5/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.1100 - categorical_accuracy: 0.9155 - val_loss: 0.0447 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0587 - categorical_accuracy: 0.9622 - val_loss: 0.0302 - val_categorical_accuracy: 0.9929 - lr: 0.0010
# Epoch 7/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0320 - categorical_accuracy: 0.9820 - val_loss: 0.0169 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 8/90
# 18/18 [==============================] - 20s 1s/step - loss: 0.0286 - categorical_accuracy: 0.9820 - val_loss: 0.0076 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/90
# 18/18 [==============================] - 23s 1s/step - loss: 0.0155 - categorical_accuracy: 0.9928 - val_loss: 0.0053 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 10/90
# 18/18 [==============================] - 20s 1s/step - loss: 0.0113 - categorical_accuracy: 0.9946 - val_loss: 0.0055 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/90
# 18/18 [==============================] - 20s 1s/step - loss: 0.0101 - categorical_accuracy: 0.9964 - val_loss: 0.0053 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 12/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0066 - categorical_accuracy: 1.0000 - val_loss: 0.0034 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 13/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0046 - categorical_accuracy: 0.9982 - val_loss: 0.0023 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 0.0023 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.0023 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.0014 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/90
# 18/18 [==============================] - 21s 1s/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.0017 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/90
# 18/18 [==============================] - 22s 1s/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/90
# 18/18 [==============================] - 20s 1s/step - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.0011 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/90
# 18/18 [==============================] - 20s 1s/step - loss: 0.0010 - categorical_accuracy: 1.0000 - val_loss: 0.0013 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/90
# 18/18 [==============================] - 20s 1s/step - loss: 7.6569e-04 - categorical_accuracy: 1.0000 - val_loss: 9.2808e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/90
# 18/18 [==============================] - 20s 1s/step - loss: 7.0407e-04 - categorical_accuracy: 1.0000 - val_loss: 8.5666e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/90
# 18/18 [==============================] - 20s 1s/step - loss: 5.9913e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0010 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/90
# 18/18 [==============================] - 20s 1s/step - loss: 5.2305e-04 - categorical_accuracy: 1.0000 - val_loss: 7.9512e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/90
# 18/18 [==============================] - 20s 1s/step - loss: 6.4106e-04 - categorical_accuracy: 1.0000 - val_loss: 9.9116e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/90
# 18/18 [==============================] - 22s 1s/step - loss: 4.5792e-04 - categorical_accuracy: 1.0000 - val_loss: 6.7588e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/90
# 18/18 [==============================] - 20s 1s/step - loss: 4.0057e-04 - categorical_accuracy: 1.0000 - val_loss: 6.4522e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/90
# 18/18 [==============================] - 20s 1s/step - loss: 3.5407e-04 - categorical_accuracy: 1.0000 - val_loss: 6.3583e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/90
# 18/18 [==============================] - 20s 1s/step - loss: 3.1107e-04 - categorical_accuracy: 1.0000 - val_loss: 6.5519e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 30/90
# 18/18 [==============================] - 21s 1s/step - loss: 2.8932e-04 - categorical_accuracy: 1.0000 - val_loss: 6.3488e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 31/90
# 18/18 [==============================] - 22s 1s/step - loss: 2.6374e-04 - categorical_accuracy: 1.0000 - val_loss: 6.1279e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 32/90
# 18/18 [==============================] - 20s 1s/step - loss: 2.4503e-04 - categorical_accuracy: 1.0000 - val_loss: 5.2939e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 33/90
# 18/18 [==============================] - 20s 1s/step - loss: 2.2384e-04 - categorical_accuracy: 1.0000 - val_loss: 5.8323e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 34/90
# 18/18 [==============================] - 20s 1s/step - loss: 2.1778e-04 - categorical_accuracy: 1.0000 - val_loss: 5.0621e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 35/90
# 18/18 [==============================] - 22s 1s/step - loss: 1.9460e-04 - categorical_accuracy: 1.0000 - val_loss: 5.4255e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 36/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.8376e-04 - categorical_accuracy: 1.0000 - val_loss: 5.1975e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 37/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.7615e-04 - categorical_accuracy: 1.0000 - val_loss: 4.8464e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 38/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.6437e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7149e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 39/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.5608e-04 - categorical_accuracy: 1.0000 - val_loss: 4.8331e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 40/90
# 18/18 [==============================] - ETA: 0s - loss: 1.4421e-04 - categorical_accuracy: 1.0000
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 18/18 [==============================] - 20s 1s/step - loss: 1.4421e-04 - categorical_accuracy: 1.0000 - val_loss: 4.9243e-04 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 41/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3685e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7659e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 42/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3588e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7553e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 43/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3510e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7271e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 44/90
# 18/18 [==============================] - 22s 1s/step - loss: 1.3425e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7204e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 45/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3369e-04 - categorical_accuracy: 1.0000 - val_loss: 4.7215e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 46/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3296e-04 - categorical_accuracy: 1.0000 - val_loss: 4.5892e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 47/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3196e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6056e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 48/90
# 18/18 [==============================] - ETA: 0s - loss: 1.3114e-04 - categorical_accuracy: 1.0000
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 18/18 [==============================] - 20s 1s/step - loss: 1.3114e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6546e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 49/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3049e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6389e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 50/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3038e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6357e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 51/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3029e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6292e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 52/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3022e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6303e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 53/90
# 18/18 [==============================] - 22s 1s/step - loss: 1.3012e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6212e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 54/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.3003e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6191e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 55/90
# 18/18 [==============================] - 20s 1s/step - loss: 1.2995e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6108e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 56/90
# 18/18 [==============================] - ETA: 0s - loss: 1.2988e-04 - categorical_accuracy: 1.0000
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 18/18 [==============================] - 20s 1s/step - loss: 1.2988e-04 - categorical_accuracy: 1.0000 - val_loss: 4.6004e-04 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 56: early stopping

# %%
df_y_test = to_categorical(y_test,num_classes=num_classes)

val_loss, val_acc = model.evaluate(x_test,df_y_test)
print(val_loss, val_acc)
# Out:
# 6/6 [==============================] - 1s 243ms/step - loss: 0.0307 - categorical_accuracy: 0.9828
# 0.03072684071958065 0.982758641242981

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis=1)

#print(y_pred[0:50])

out_acc = accuracy_score(y_test, y_pred)
out_f1 = f1_score(y_test, y_pred,average ='micro')

print("Accuracy: {}".format(round(out_acc,4)))
print("F1 Score(micro): {}".format(round(out_f1,4)))

out_f1 = f1_score(y_test, y_pred,average ='macro')
print("F1 Score(macro): {}".format(round(out_f1,4)))

out_f1 = f1_score(y_test, y_pred,average ='weighted')
print("F1 Score(weighted): {}".format(round(out_f1,4)))
# Out:
# 6/6 [==============================] - 2s 244ms/step
# Accuracy: 0.9828
# F1 Score(micro): 0.9828
# F1 Score(macro): 0.981
# F1 Score(weighted): 0.9827
